# %%
import os

# This is for showing the Tensorflow log
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# This is for parsing the X data, you can ignore it if you do not need preprocessing
def format_data_x(datafile):
    x_data = None
    for item in datafile:
        item_data = np.loadtxt(item, dtype=np.float)
        if x_data is None:
            x_data = np.zeros((len(item_data), 1))
        x_data = np.hstack((x_data, item_data))
    x_data = x_data[:, 1:]
    print(x_data.shape)
    X = None
    for i in range(len(x_data)):
        row = np.asarray(x_data[i, :])
        row = row.reshape(9, 128).T
        if X is None:
            X = np.zeros((len(x_data), 128, 9))
        X[i] = row
    print(X.shape)
    return X


# This is for parsing the Y data, you can ignore it if you do not need preprocessing
def format_data_y(datafile):
    data = np.loadtxt(datafile, dtype=np.int) - 1
    YY = np.eye(6)[data]
    return YY


# Load data function, if there exists parsed data file, then use it
# If not, parse the original dataset from scratch
def load_data():
    import os
    if os.path.isfile('data/data_har.npz') == True:
        data = np.load('data/data_har.npz')
        X_train = data['X_train']
        Y_train = data['Y_train']
        X_test = data['X_test']
        Y_test = data['Y_test']
    else:
        # This for processing the dataset from scratch
        # After downloading the dataset, put it to somewhere that str_folder can find
        str_folder = 'Your root folder' + 'UCI HAR Dataset/'
        INPUT_SIGNAL_TYPES = [
            "body_acc_x_",
            "body_acc_y_",
            "body_acc_z_",
            "body_gyro_x_",
            "body_gyro_y_",
            "body_gyro_z_",
            "total_acc_x_",
            "total_acc_y_",
            "total_acc_z_"
        ]

        str_train_files = [str_folder + 'train/' + 'Inertial Signals/' + item + 'train.txt' for item in
                           INPUT_SIGNAL_TYPES]
        str_test_files = [str_folder + 'test/' + 'Inertial Signals/' + item + 'test.txt' for item in INPUT_SIGNAL_TYPES]
        str_train_y = str_folder + 'train/y_train.txt'
        str_test_y = str_folder + 'test/y_test.txt'

        X_train = format_data_x(str_train_files)
        X_test = format_data_x(str_test_files)
        Y_train = format_data_y(str_train_y)
        Y_test = format_data_y(str_test_y)

    return X_train, Y_train, X_test, Y_test


# A class for some hyperparameters
class Config(object):
    def __init__(self, X_train, Y_train):
        self.n_input = len(X_train[0])  # number of input neurons to the network
        self.n_output = len(Y_train[0])  # number of output neurons
        self.dropout = 0.9  # dropout, between 0 and 1
        self.learning_rate = 0.001  # learning rate, float
        self.training_epoch = 100# training epoch
        self.n_channel = 9  # number of input channel
        self.input_height = 128  # input height
        self.input_width = 1  # input width
        self.kernel_size = 13  # number of convolution kernel size
        self.depth = 32  # number of convolutions
        self.batch_size = 16  # batch size
        self.show_progress = 100  # how many batches to show the progress

        # weights and biases definition
        self.weights = {
            'wc1': tf.Variable(tf.random_normal([1, self.kernel_size, self.n_channel, self.depth])),
            'wc2': tf.Variable(tf.random_normal([1, self.kernel_size, self.depth, 64])),
            'wd1': tf.Variable(tf.random_normal([32 * 32 * 2, 1000])),
            'wd2': tf.Variable(tf.random_normal([1000, 500])),
            'wd3': tf.Variable(tf.random_normal([500, 300])),
            'out': tf.Variable(tf.random_normal([300, self.n_output]))
        }

        self.biases = {
            'bc1': tf.Variable(tf.random_normal([self.depth])),
            'bc2': tf.Variable(tf.random_normal([64])),
            'bd1': tf.Variable(tf.random_normal([1000])),
            'bd2': tf.Variable(tf.random_normal([500])),
            'bd3': tf.Variable(tf.random_normal([300])),
            'out': tf.Variable(tf.random_normal([self.n_output]))
        }


# wrap of conv1d
def conv1d(x, W, b, stride):
    x = tf.nn.conv2d(x, W, strides=[1, stride, 1, 1], padding='SAME')
    x = tf.add(x, b)
    return tf.nn.relu(x)


# wrap of maxpool1d
def maxpool1d(x, kernel_size, stride):
    return tf.nn.max_pool(x, ksize=[1, kernel_size, 1, 1], strides=[1, stride, 1, 1], padding='VALID')


# network definition
def conv_net(x, W, b, dropout):
    conv1 = conv1d(x, W['wc1'], b['bc1'], 1)
    conv1 = maxpool1d(conv1, 2, stride=2)
    conv2 = conv1d(conv1, W['wc2'], b['bc2'], 1)
    conv2 = maxpool1d(conv2, 2, stride=2)
    conv2 = tf.reshape(conv2, [-1, W['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(conv2, W['wd1']), b['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, keep_prob=dropout)
    fc2 = tf.add(tf.matmul(fc1, W['wd2']), b['bd2'])
    fc2 = tf.nn.relu(fc2)
    fc2 = tf.nn.dropout(fc2, keep_prob=dropout)
    fc3 = tf.add(tf.matmul(fc2, W['wd3']), b['bd3'])
    fc3 = tf.nn.relu(fc3)
    fc3 = tf.nn.dropout(fc3, keep_prob=dropout)
    out = tf.add(tf.matmul(fc3, W['out']), b['out'])
    return out


# wrap the network for training and testing
def network(X_train, Y_train, X_test, Y_test):
    config = Config(X_train, Y_train)
    
    # X, Y and keep_prob are three feeds to the network
    X = tf.placeholder(tf.float32, shape=[None, config.input_height, config.input_width, config.n_channel])
    Y = tf.placeholder(tf.float32, shape=[None, config.n_output])
    keep_prob = tf.placeholder(tf.float32)

    y_pred = conv_net(X, config.weights, config.biases, config.dropout)
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y, logits=y_pred))
    optimizer = tf.train.AdamOptimizer(learning_rate=config.learning_rate).minimize(cost)

    correct_pred = tf.equal(tf.arg_max(y_pred, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    total_batch = len(X_train) // config.batch_size

    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        train_loss = []
        test_loss = []
        train_accuracy = []
        test_accuracy = []
        for i in range(config.training_epoch):
            for j in range(total_batch):
                x_train_batch, y_train_batch = X_train[j * config.batch_size: config.batch_size * (j + 1)], \
                                               Y_train[j * config.batch_size: config.batch_size * (j + 1)]
                x_train_batch = np.reshape(x_train_batch, [len(x_train_batch), 128, 1, 9])
                sess.run(optimizer, feed_dict={X: x_train_batch, Y: y_train_batch, keep_prob: config.dropout})
                if j % config.show_progress == 0:
                    loss, acc = sess.run([cost, accuracy],
                                         feed_dict={X: x_train_batch,
                                                    Y: y_train_batch,
                                                    keep_prob: config.dropout})
                    print('Epoch:%02d,batch:%03d,loss:%.8f,accuracy:%.8f' % (
                        i + 1, (j + 1) * config.batch_size, loss, acc))
            acc_test,valid_loss = sess.run([accuracy,cost], feed_dict={X: np.reshape(X_test, [len(X_test), 128, 1, 9]),
                                                 Y: np.reshape(Y_test, [len(Y_test), 6]),
                                                 keep_prob: 1.})
            train_loss.append(loss)
            test_loss.append(valid_loss)
            train_accuracy.append(acc)
            test_accuracy.append(acc_test)
        print('Optimization finished!')
        
        print('Accuracy of testing:%.8f' % acc_test)
        #test_acc,valid_loss = sess.run([accuracy,cost], feed_dict={x: test_X,y : test_y})
        
    plt.plot(range(len(train_loss)), train_accuracy, 'b', label='Training Accuracy')
    plt.plot(range(len(train_loss)), test_accuracy, 'r', label='Test Accuracy')
    plt.title('Training and Test Accuracy')
    plt.xlabel('Epochs ',fontsize=16)
    plt.ylabel('Loss',fontsize=16)
    plt.legend()
    plt.figure()
    plt.show()
    
    plt.plot(range(len(train_loss)), train_loss, 'b', label='Training loss')
    plt.plot(range(len(train_loss)), test_loss, 'r', label='Test loss')
    plt.title('Training and Test loss')
    plt.xlabel('Epochs ',fontsize=16)
    plt.ylabel('Loss',fontsize=16)
    plt.legend()
    plt.figure()
    plt.show()


if __name__ == '__main__':
    X_train, Y_train, X_test, Y_test = load_data()
    # normalizing the data
    X_train = (X_train - np.mean(X_train)) / np.std(X_train)
    X_test = (X_test - np.mean(X_test)) / np.std(X_test)
    # build the network
    network(X_train, Y_train, X_test, Y_test)
# Out:
# Epoch:01,batch:016,loss:2153875.00000000,accuracy:0.00000000
# Epoch:01,batch:1616,loss:335058.87500000,accuracy:0.50000000
# Epoch:01,batch:3216,loss:768319.75000000,accuracy:0.37500000
# Epoch:01,batch:4816,loss:319287.93750000,accuracy:0.56250000
# Epoch:01,batch:6416,loss:225329.73437500,accuracy:0.50000000
# Epoch:02,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:02,batch:1616,loss:203899.85937500,accuracy:0.75000000
# Epoch:02,batch:3216,loss:396814.09375000,accuracy:0.37500000
# Epoch:02,batch:4816,loss:345643.50000000,accuracy:0.50000000
# Epoch:02,batch:6416,loss:19018.87890625,accuracy:0.87500000
# Epoch:03,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:03,batch:1616,loss:45360.06640625,accuracy:0.87500000
# Epoch:03,batch:3216,loss:294330.15625000,accuracy:0.62500000
# Epoch:03,batch:4816,loss:180348.28125000,accuracy:0.68750000
# Epoch:03,batch:6416,loss:36395.41406250,accuracy:0.93750000
# Epoch:04,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:04,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:04,batch:3216,loss:162291.00000000,accuracy:0.50000000
# Epoch:04,batch:4816,loss:22524.91406250,accuracy:0.93750000
# Epoch:04,batch:6416,loss:12625.18652344,accuracy:0.81250000
# Epoch:05,batch:016,loss:562.06054688,accuracy:0.87500000
# Epoch:05,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:05,batch:3216,loss:142945.48437500,accuracy:0.75000000
# Epoch:05,batch:4816,loss:1035.34570312,accuracy:0.93750000
# Epoch:05,batch:6416,loss:10403.82421875,accuracy:0.81250000
# Epoch:06,batch:016,loss:841.64453125,accuracy:0.93750000
# Epoch:06,batch:1616,loss:16823.01953125,accuracy:0.93750000
# Epoch:06,batch:3216,loss:147330.06250000,accuracy:0.68750000
# Epoch:06,batch:4816,loss:72226.45312500,accuracy:0.75000000
# Epoch:06,batch:6416,loss:53531.83593750,accuracy:0.81250000
# Epoch:07,batch:016,loss:1963.83984375,accuracy:0.93750000
# Epoch:07,batch:1616,loss:31854.46484375,accuracy:0.81250000
# Epoch:07,batch:3216,loss:50085.80859375,accuracy:0.87500000
# Epoch:07,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:07,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:08,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:08,batch:1616,loss:2042.10888672,accuracy:0.93750000
# Epoch:08,batch:3216,loss:72008.99218750,accuracy:0.81250000
# Epoch:08,batch:4816,loss:559.85156250,accuracy:0.93750000
# Epoch:08,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:09,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:09,batch:1616,loss:3802.45312500,accuracy:0.87500000
# Epoch:09,batch:3216,loss:47471.25781250,accuracy:0.87500000
# Epoch:09,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:09,batch:6416,loss:3100.29687500,accuracy:0.93750000
# Epoch:10,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:10,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:10,batch:3216,loss:26831.29296875,accuracy:0.81250000
# Epoch:10,batch:4816,loss:15128.48046875,accuracy:0.93750000
# Epoch:10,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:11,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:11,batch:1616,loss:4306.28515625,accuracy:0.93750000
# Epoch:11,batch:3216,loss:41074.83984375,accuracy:0.81250000
# Epoch:11,batch:4816,loss:2654.50000000,accuracy:0.93750000
# Epoch:11,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:12,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:12,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:12,batch:3216,loss:13898.18945312,accuracy:0.87500000
# Epoch:12,batch:4816,loss:4939.11718750,accuracy:0.93750000
# Epoch:12,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:13,batch:016,loss:60.60546875,accuracy:0.93750000
# Epoch:13,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:13,batch:3216,loss:6738.16015625,accuracy:0.81250000
# Epoch:13,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:13,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:14,batch:016,loss:2855.08789062,accuracy:0.87500000
# Epoch:14,batch:1616,loss:15294.01562500,accuracy:0.93750000
# Epoch:14,batch:3216,loss:28759.83203125,accuracy:0.93750000
# Epoch:14,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:14,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:15,batch:016,loss:1779.49804688,accuracy:0.87500000
# Epoch:15,batch:1616,loss:2535.21289062,accuracy:0.93750000
# Epoch:15,batch:3216,loss:8437.19921875,accuracy:0.93750000
# Epoch:15,batch:4816,loss:1023.88281250,accuracy:0.93750000
# Epoch:15,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:16,batch:016,loss:766.35839844,accuracy:0.93750000
# Epoch:16,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:16,batch:3216,loss:21382.16210938,accuracy:0.87500000
# Epoch:16,batch:4816,loss:2510.20312500,accuracy:0.93750000
# Epoch:16,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:17,batch:016,loss:5174.01123047,accuracy:0.81250000
# Epoch:17,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:17,batch:3216,loss:3776.47460938,accuracy:0.93750000
# Epoch:17,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:17,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:18,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:18,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:18,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:18,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:18,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:19,batch:016,loss:344.74975586,accuracy:0.93750000
# Epoch:19,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:19,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:19,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:19,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:20,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:20,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:20,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:20,batch:4816,loss:6350.86328125,accuracy:0.81250000
# Epoch:20,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:21,batch:016,loss:570.11621094,accuracy:0.93750000
# Epoch:21,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:21,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:21,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:21,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:22,batch:016,loss:783.17871094,accuracy:0.93750000
# Epoch:22,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:22,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:22,batch:4816,loss:13183.92578125,accuracy:0.93750000
# Epoch:22,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:23,batch:016,loss:1339.51318359,accuracy:0.87500000
# Epoch:23,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:23,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:23,batch:4816,loss:850.82421875,accuracy:0.93750000
# Epoch:23,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:24,batch:016,loss:289.98144531,accuracy:0.87500000
# Epoch:24,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:24,batch:3216,loss:16819.67382812,accuracy:0.93750000
# Epoch:24,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:24,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:25,batch:016,loss:171.12207031,accuracy:0.87500000
# Epoch:25,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:25,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:25,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:25,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:26,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:26,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:26,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:26,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:26,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:27,batch:016,loss:44.60742188,accuracy:0.93750000
# Epoch:27,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:27,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:27,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:27,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:28,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:28,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:28,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:28,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:28,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:29,batch:016,loss:1163.82861328,accuracy:0.87500000
# Epoch:29,batch:1616,loss:11648.94335938,accuracy:0.81250000
# Epoch:29,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:29,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:29,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:30,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:30,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:30,batch:3216,loss:1051.53320312,accuracy:0.93750000
# Epoch:30,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:30,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:31,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:31,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:31,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:31,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:31,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:32,batch:016,loss:257.34326172,accuracy:0.93750000
# Epoch:32,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:32,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:32,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:32,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:33,batch:016,loss:26.15283203,accuracy:0.93750000
# Epoch:33,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:33,batch:3216,loss:7208.25585938,accuracy:0.93750000
# Epoch:33,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:33,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:34,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:34,batch:1616,loss:5467.66601562,accuracy:0.93750000
# Epoch:34,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:34,batch:4816,loss:3368.74218750,accuracy:0.93750000
# Epoch:34,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:35,batch:016,loss:27.57910156,accuracy:0.93750000
# Epoch:35,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:35,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:35,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:35,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:36,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:36,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:36,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:36,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:36,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:37,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:37,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:37,batch:3216,loss:14750.27539062,accuracy:0.93750000
# Epoch:37,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:37,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:38,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:38,batch:1616,loss:339.37109375,accuracy:0.93750000
# Epoch:38,batch:3216,loss:12312.88183594,accuracy:0.93750000
# Epoch:38,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:38,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:39,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:39,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:39,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:39,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:39,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:40,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:40,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:40,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:40,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:40,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:41,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:41,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:41,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:41,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:41,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:42,batch:016,loss:129.00732422,accuracy:0.93750000
# Epoch:42,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:42,batch:3216,loss:8519.71386719,accuracy:0.93750000
# Epoch:42,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:42,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:43,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:43,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:43,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:43,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:43,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:44,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:44,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:44,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:44,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:44,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:45,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:45,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:45,batch:3216,loss:707.72167969,accuracy:0.93750000
# Epoch:45,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:45,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:46,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:46,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:46,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:46,batch:4816,loss:3292.94921875,accuracy:0.93750000
# Epoch:46,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:47,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:47,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:47,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:47,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:47,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:48,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:48,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:48,batch:3216,loss:563.54687500,accuracy:0.93750000
# Epoch:48,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:48,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:49,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:49,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:49,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:49,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:49,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:50,batch:016,loss:379.11425781,accuracy:0.93750000
# Epoch:50,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:50,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:50,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:50,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:51,batch:016,loss:34.60888672,accuracy:0.93750000
# Epoch:51,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:51,batch:3216,loss:1735.45312500,accuracy:0.93750000
# Epoch:51,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:51,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:52,batch:016,loss:112.67968750,accuracy:0.93750000
# Epoch:52,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:52,batch:3216,loss:10284.93945312,accuracy:0.93750000
# Epoch:52,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:52,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:53,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:53,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:53,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:53,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:53,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:54,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:54,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:54,batch:3216,loss:15281.50390625,accuracy:0.93750000
# Epoch:54,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:54,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:55,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:55,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:55,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:55,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:55,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:56,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:56,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:56,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:56,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:56,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:57,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:57,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:57,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:57,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:57,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:58,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:58,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:58,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:58,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:58,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:59,batch:016,loss:1.15747070,accuracy:0.93750000
# Epoch:59,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:59,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:59,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:59,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:60,batch:016,loss:2.20751953,accuracy:0.93750000
# Epoch:60,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:60,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:60,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:60,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:61,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:61,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:61,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:61,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:61,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:62,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:62,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:62,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:62,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:62,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:63,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:63,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:63,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:63,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:63,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:64,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:64,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:64,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:64,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:64,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:65,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:65,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:65,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:65,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:65,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:66,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:66,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:66,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:66,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:66,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:67,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:67,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:67,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:67,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:67,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:68,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:68,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:68,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:68,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:68,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:69,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:69,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:69,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:69,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:69,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:70,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:70,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:70,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:70,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:70,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:71,batch:016,loss:0.87939459,accuracy:0.93750000
# Epoch:71,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:71,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:71,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:71,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:72,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:72,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:72,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:72,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:72,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:73,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:73,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:73,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:73,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:73,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:74,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:74,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:74,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:74,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:74,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:75,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:75,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:75,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:75,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:75,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:76,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:76,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:76,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:76,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:76,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:77,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:77,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:77,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:77,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:77,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:78,batch:016,loss:9.96459961,accuracy:0.93750000
# Epoch:78,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:78,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:78,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:78,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:79,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:79,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:79,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:79,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:79,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:80,batch:016,loss:25.74438477,accuracy:0.93750000
# Epoch:80,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:80,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:80,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:80,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:81,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:81,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:81,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:81,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:81,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:82,batch:016,loss:0.00000004,accuracy:1.00000000
# Epoch:82,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:82,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:82,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:82,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:83,batch:016,loss:1.57739258,accuracy:0.93750000
# Epoch:83,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:83,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:83,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:83,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:84,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:84,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:84,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:84,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:84,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:85,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:85,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:85,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:85,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:85,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:86,batch:016,loss:0.00000326,accuracy:1.00000000
# Epoch:86,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:86,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:86,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:86,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:87,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:87,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:87,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:87,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:87,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:88,batch:016,loss:19.99560928,accuracy:0.87500000
# Epoch:88,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:88,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:88,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:88,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:89,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:89,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:89,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:89,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:89,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:90,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:90,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:90,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:90,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:90,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:91,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:91,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:91,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:91,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:91,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:92,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:92,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:92,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:92,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:92,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:93,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:93,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:93,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:93,batch:4816,loss:4234.39843750,accuracy:0.93750000
# Epoch:93,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:94,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:94,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:94,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:94,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:94,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:95,batch:016,loss:4.72139120,accuracy:0.87500000
# Epoch:95,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:95,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:95,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:95,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:96,batch:016,loss:1.95948935,accuracy:0.93750000
# Epoch:96,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:96,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:96,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:96,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:97,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:97,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:97,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:97,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:97,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:98,batch:016,loss:0.00000001,accuracy:1.00000000
# Epoch:98,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:98,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:98,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:98,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:99,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:99,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:99,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:99,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:99,batch:6416,loss:0.00000000,accuracy:1.00000000
# Epoch:100,batch:016,loss:0.00000000,accuracy:1.00000000
# Epoch:100,batch:1616,loss:0.00000000,accuracy:1.00000000
# Epoch:100,batch:3216,loss:0.00000000,accuracy:1.00000000
# Epoch:100,batch:4816,loss:0.00000000,accuracy:1.00000000
# Epoch:100,batch:6416,loss:0.00000000,accuracy:1.00000000
# Optimization finished!
# Accuracy of testing:0.85442823
